# %%
import pandas as pd
import requests

# %%
def get_character(char_name, char_realm, char_region):
    response = requests.get('https://raider.io/api/v1/characters/profile?region='+
                             char_region + '&realm='+
                             char_realm+'&name='+
                             char_name+'&fields=gear%2Ccovenant%2Cmythic_plus_scores_by_season%3Acurrent%2Cmythic_plus_ranks%2C')
    return response.json()

# %%
def get_leaderboard():
    response = requests.get('https://raider.io/api/v1/mythic-plus/runs?season=season-sl-1&region=world&dungeon=all&page=0')
    return response.json()

# %%
char_name = 'skyl%C3%ADne'
char_realm = 'hellfire'
char_region = 'eu'

data = get_character(char_name,char_realm,char_region)
df = pd.json_normalize(data)
columns = ['name','race','class','active_spec_name','active_spec_role','gender',
           'faction','achievement_points','region','realm','covenant.name','covenant.renown_level','gear.item_level_equipped',
           'gear.items.head.name','gear.items.neck.name','gear.items.shoulder.name','gear.items.back.name','gear.items.chest.name',
           'gear.items.waist.name','gear.items.shirt.name','gear.items.wrist.name','gear.items.hands.name','gear.items.legs.name',
           'gear.items.feet.name','gear.items.finger1.name','gear.items.finger2.name','gear.items.trinket1.name',
           'gear.items.trinket2.name','gear.items.mainhand.name','gear.items.offhand.name','mythic_plus_scores_by_season']
df = df[ columns]
df['score'] = df['mythic_plus_scores_by_season'].apply(pd.Series)[0].apply(pd.Series)['scores'].apply(pd.Series)['tank']
df.drop('mythic_plus_scores_by_season',axis=1)
# Out:
#       name   race    class active_spec_name active_spec_role gender   faction  \
# 0  Skylíne  Human  Paladin       Protection             TANK   male  alliance
#
#    achievement_points region     realm  ...   gear.items.hands.name  \
# 0               30760     eu  Hellfire  ...  Guilewind Stone Talons
#
#          gear.items.legs.name          gear.items.feet.name  \
# 0  Legplates of Unholy Frenzy  Stoneguard Attendant's Boots
#
#    gear.items.finger1.name gear.items.finger2.name gear.items.trinket1.name  \
# 0  Entwined Gorger Tendril      Death God's Signet  Slimy Consumptive Organ
#
#   gear.items.trinket2.name   gear.items.mainhand.name  \
# 0      Anima Field Emitter  Sophisticated Bonecracker
#
#            gear.items.offhand.name  score
# 0  Barricade of the Endless Empire  611.7
#
# [1 rows x 31 columns]

# %%
data2 = get_leaderboard()
df2 = pd.json_normalize(data2, record_path = ['rankings'])
df2.head(2)
# Out:
#    rank  score   run.season  run.dungeon.id       run.dungeon.name  \
# 0     1  316.2  season-sl-1           13334  Mists of Tirna Scithe
# 1     2  315.7  season-sl-1           13228             Plaguefall
#
#   run.dungeon.short_name       run.dungeon.slug  run.dungeon.expansion_id  \
# 0                  MISTS  mists-of-tirna-scithe                         8
# 1                     PF             plaguefall                         8
#
#   run.dungeon.patch  run.dungeon.keystone_timer_ms  ...  \
# 0             9.0.2                        1800999  ...
# 1             9.0.2                        2280999  ...
#
#    run.time_remaining_ms  run.faction  \
# 0                 158318        horde
# 1                 157050        horde
#
#                                 run.weekly_modifiers  \
# 0  [{'id': 10, 'icon': 'ability_toughness', 'name...
# 1  [{'id': 10, 'icon': 'ability_toughness', 'name...
#
#    run.num_modifiers_active  \
# 0                         4
# 1                         4
#
#                                           run.roster  run.platoon.name  \
# 0  [{'character': {'id': 9205267, 'persona_id': 2...         WUNDERBAR
# 1  [{'character': {'id': 22316768, 'persona_id': ...        Nice Clock
#
#   run.platoon.short_name  run.platoon.slug  run.platoon.id run.platoon
# 0              WUNDERBAR         wunderbar          4041.0         NaN
# 1             Nice Clock        nice-clock          4265.0         NaN
#
# [2 rows x 28 columns]

# %%
df2.to_csv('tester.csv')
